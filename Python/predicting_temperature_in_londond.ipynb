# %% [markdown]
# ## <center> Predicting Temperature in London <center>

# %%
# Run this cell to import the modules you require
import pandas as pd
import numpy as np
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# Import the datset
df = pd.read_csv("C:/Users/uyen/Desktop/Real-World-Projects/Python/datasets/london_weather.csv")
df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
# Dataframe's number of rows and columns
df.shape
# Out:
# (15341, 10)

# %%
# Checking for missing data
df.isna().sum()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64

# %%
# Boxplot to observe the distribution of 'cloud_cover' 
sns.boxplot(df["cloud_cover"])
plt.title("The Distribution of Cloud Cover")
plt.ylabel("Cloud Cover (oktas)")
plt.show()

# %%
# Boxplot to observe the distribution of 'global_radiation'
sns.boxplot(df["global_radiation"])
plt.title("The Distribution of Global Radiation")
plt.ylabel("Global Radiation (W/m2)")
plt.show()

# %%
# Boxplot to observe the distribution of 'max_temp'
sns.boxplot(df["max_temp"])
plt.title("The Distribution of Maximum Temperature")
plt.ylabel("Maximum Temperature (*C)")
plt.show()

# %%
# Boxplot to observe the distribution of 'mean_temp'
sns.boxplot(df["mean_temp"])
plt.title("The Distribution of Mean Temperature")
plt.ylabel("Mean Temperature (*C)")
plt.show()

# %%
# Boxplot to observe the distribution of 'min_temp'
sns.boxplot(df["min_temp"])
plt.title("The Distribution of Minimum Temperature")
plt.ylabel("Minimum Temperature (*C)")
plt.show()

# %%
# Boxplot to observe the distribution of precipitation
sns.boxplot(df["precipitation"])
plt.title("The Distribution of Precipitation")
plt.ylabel("Precipitation (mm)")
plt.show()

# %%
# Boxplot to observe the distribution of pressure
sns.boxplot(df["pressure"])
plt.title("The Distribution of Pressure")
plt.ylabel("Pressure (Pa)")
plt.show()

# %%
# Boxplot to observe the distribution of 'snow_depth'
sns.boxplot(df["snow_depth"])
plt.title("The Distribution of Snow Depth")
plt.ylabel("Snow Depth (cm)")
plt.show()
