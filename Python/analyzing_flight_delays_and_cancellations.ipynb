# %% [markdown]
# ## <center> Analyzing Flight Delays and Cancellations <center>

# %%
# Import necessary libraries
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Import flights dataset
flights = pd.read_csv("C:/Users/uyen/Desktop/Real-World-Projects/Python/datasets/flights2022.csv")
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2022      1    1       1.0            2359        2.0     604.0
# 1  2022      1    1       1.0            2250       71.0     242.0
# 2  2022      1    1      10.0            2355       15.0     759.0
# 3  2022      1    1      25.0            2350       35.0     606.0
# 4  2022      1    1      35.0            2349       46.0     616.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             618      -14.0      UA     555  N405UA    SEA  IAH     221.0
# 1             142       60.0      AS      72  N265AK    SEA  FAI     193.0
# 2             730       29.0      AS     270  N274AK    SEA  ATL     261.0
# 3             550       16.0      AS       7  N281AK    SEA  ORD     193.0
# 4             545       31.0      UA     507  N426UA    PDX  ORD     196.0
#
#    distance  hour  minute             time_hour                airline
# ...

# %%
# Import weather dataset
weather = pd.read_csv("C:/Users/uyen/Desktop/Real-World-Projects/Python/datasets/flights_weather2022.csv")
weather.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2022      1    1       1.0            2359        2.0     604.0
# 1  2022      1    1       1.0            2250       71.0     242.0
# 2  2022      1    1      10.0            2355       15.0     759.0
# 3  2022      1    1      25.0            2350       35.0     606.0
# 4  2022      1    1      35.0            2349       46.0     616.0
#
#    sched_arr_time  arr_delay carrier  ...    route  temp  dewp  humid  \
# 0             618      -14.0      UA  ...  SEA-IAH  33.0  23.0  66.06
# 1             142       60.0      AS  ...  SEA-FAI  32.0  23.0  69.04
# 2             730       29.0      AS  ...  SEA-ATL  33.0  23.0  66.06
# 3             550       16.0      AS  ...  SEA-ORD  33.0  23.0  66.06
# 4             545       31.0      UA  ...  PDX-ORD  33.0  19.0  55.75
#
#    wind_dir  wind_speed  wind_gust  precip pressure visib
# 0     160.0     8.05546   9.270062     0.0   1022.9  10.0
# ...

# %%
# Create the route column in the flights dataset
flights["route"] = flights["origin"] + '-' + flights["dest"]
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2022      1    1       1.0            2359        2.0     604.0
# 1  2022      1    1       1.0            2250       71.0     242.0
# 2  2022      1    1      10.0            2355       15.0     759.0
# 3  2022      1    1      25.0            2350       35.0     606.0
# 4  2022      1    1      35.0            2349       46.0     616.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0             618      -14.0      UA  ...   N405UA    SEA  IAH    221.0
# 1             142       60.0      AS  ...   N265AK    SEA  FAI    193.0
# 2             730       29.0      AS  ...   N274AK    SEA  ATL    261.0
# 3             550       16.0      AS  ...   N281AK    SEA  ORD    193.0
# 4             545       31.0      UA  ...   N426UA    PDX  ORD    196.0
#
#    distance  hour  minute             time_hour                airline  \
# ...

# %%
# Observe the unique routes for flights
unique_flights = flights["route"].unique()

# %%
# Observe the unique origin airports
flights["origin"].unique()
# Out:
# array(['SEA', 'PDX'], dtype=object)

# %%
# Observe the unique dest airports
flights["dest"].unique()
# Out:
# array(['IAH', 'FAI', 'ATL', 'ORD', 'JFK', 'MIA', 'PSC', 'IAD', 'DEN',
#        'PHX', 'MDW', 'OAK', 'DFW', 'LAS', 'SLC', 'PDX', 'SJC', 'CLT',
#        'SNA', 'DTW', 'LAX', 'SEA', 'SAN', 'SFO', 'MSP', 'ONT', 'ANC',
#        'PSP', 'HNL', 'ICT', 'MSO', 'KOA', 'STS', 'BOS', 'BOI', 'CMH',
#        'OKC', 'SBA', 'SMF', 'DAL', 'TUS', 'PHL', 'GEG', 'FLL', 'AUS',
#        'OGG', 'LIH', 'BZN', 'RDU', 'RSW', 'STL', 'DCA', 'MRY', 'MCO',
#        'EWR', 'MFR', 'BLI', 'FAT', 'RDM', 'EUG', 'TPA', 'BIL', 'ABQ',
#        'IND', 'FCA', 'CVG', 'BUR', 'MCI', 'PIT', 'OMA', 'PUW', 'MSY',
#        'JAC', 'MKE', 'RNO', 'ALW', 'HLN', 'BNA', 'SAT', 'EAT', 'HDN',
#        'JNU', 'YKM', 'GTF', 'ELP', 'SUN', 'KTN', 'SBP', 'RDD', 'IDA',
#        'BWI', 'CHS', 'PAE', 'GRR', 'DSM', 'SIT', 'CLE'], dtype=object)

# %%
# Calculate the average departure delays in minutes for routes
avg_delay_routes = pd.DataFrame(flights.groupby(["route"])["dep_delay"].mean()).reset_index()
avg_delay_routes
# Out:
#        route  dep_delay
# 0    PDX-ABQ   1.098039
# 1    PDX-ANC   4.748936
# 2    PDX-ATL   7.020979
# 3    PDX-AUS   5.435374
# 4    PDX-BOI   5.136430
# ..       ...        ...
# 144  SEA-STS   6.782493
# 145  SEA-SUN   5.735537
# 146  SEA-TPA   6.537344
# 147  SEA-TUS   6.161290
# 148  SEA-YKM   5.427350
#
# [149 rows x 2 columns]

# %%
# Observe the cancelled flights
flights[flights["dep_time"].isna()]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 485     2022      1    1       NaN            1845        NaN       NaN
# 486     2022      1    1       NaN             945        NaN       NaN
# 487     2022      1    1       NaN            1327        NaN       NaN
# 488     2022      1    1       NaN            1715        NaN       NaN
# 489     2022      1    1       NaN            1515        NaN       NaN
# ...      ...    ...  ...       ...             ...        ...       ...
# 111371  2022      6   30       NaN            1155        NaN       NaN
# 111372  2022      6   30       NaN            1448        NaN       NaN
# 111373  2022      6   30       NaN            1751        NaN       NaN
# 111374  2022      6   30       NaN            1145        NaN       NaN
# 111375  2022      6   30       NaN             720        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# ...
